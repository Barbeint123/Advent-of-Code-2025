# %%
# --- PART 1 -----

# The data lists nodes and their exit points
# EX                  Interpretation
# aaa: you hhh        aaa exits at, "you" and "hhh"

# EX
# DATA                        Possible paths (5)
# aaa: you hhh                 you --> bbb --> ddd --> ggg --> out
# you: bbb ccc                 you --> bbb --> eee --> out
# bbb: ddd eee                 you --> ccc --> ddd --> ggg --> out
# ccc: ddd eee fff             you --> ccc --> eee --> out
# ddd: ggg                     you --> ccc --> fff --> out
# eee: out                    
# fff: out                    
# ggg: out                    
# hhh: ccc fff iii
# iii: out

# password: the # paths that lead from you -> out
