# %%
# --- PART 1 -----

# Each row in the data describes a machine
# each machine contains a three components:

# [] = a light diagram. 
#   All lights are intially off, but must be turned on accoridng to the diagram
#   Machines may have different number of lights
#   EX: [.##.] -->  light 0 and 4 must be turned off, light 1 and 2 on 

# () - a number of buttons.
#    Buttons turn on the lights listed in the parantheses
#    EX: (0,3,4) ---->  the light 0, 3 and 4 toggles
#        [#.....] ---> [...##.]

# {} - joltage requirements
#    this can be ignored for now

# EX:
#   DATA                                        Fewest buttons                 
#   [.##.] (3) (1,3) (2) (2,3) (0,2) (0,1)      press (0,2) and (0,1) once each

# [....]  --(0,2)->  [#.#.]  --(0,1)-> [.##.]

# password: the sum of the fewest button presses per machine 

# Insight: each button needs to be pressed at most once
