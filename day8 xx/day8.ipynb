# %%
# --- PART 1 -----

# each row in the data represents the coordinates of a node (x,y,z)

# iterate through the data, connecting the closest two nodes for each iteration
# connected nodes form a cluster
# continue until all nodes have at least one connection

# password: the three largest clusters multiplied

# %%
# --- PART 1 -----

# Each row represents a node coordinate (x,y,z)

# Compute all pairwise distances between nodes and sort by distance

# Iterate through the 1000 closest pairs:
#   - If the two nodes are already in the same circuit (cluster), do nothing
#   - Otherwise, merge their clusters

# Password: multiply together the sizes of the three largest clusters
